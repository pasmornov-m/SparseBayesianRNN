# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import time
import sys

from Code.PTB_data_utils import PTB_word, load_PTB_word

# %%
def alpha_regf(a: torch.Tensor) -> torch.Tensor:
    return 0.5 * torch.log1p(torch.exp(-a)) - (
        0.03 + 1.0 / (1.0 + torch.exp(-(1.5 * (a + 1.3)))) * 0.64
    )

def hard_sigmoid(x: torch.Tensor) -> torch.Tensor:
    return torch.clamp(0.2 * x + 0.5, min=0.0, max=1.0)

def alloc_zeros_matrix_torch(*dims, dtype=torch.float32, device="cpu"):
    return torch.zeros(*dims, dtype=dtype, device=device)

# %%
class LSTM(nn.Module):
    def __init__(self,
                 incoming,
                 num_units,
                 ingate=None,
                 forgetgate=None,
                 cell=None,
                 outgate=None,
                 hid_init=0.0,
                 cell_init=0.0,
                 learn_init=True,
                 nonlinearity=torch.tanh,
                 backwards=False,
                 gradient_steps=-1,
                 mask_input=None,
                 only_return_final=False,
                 hid_prop=False,
                 **kwargs):
        
        incomings = incoming if hid_prop else [incoming]
        self.mask_incoming_index = -1
        if mask_input is not None:
            incomings.append(mask_input)
            self.mask_incoming_index = len(incomings)-1
        super().__init__()

        self.name = "LSTM"
        self.nonlinearity = nonlinearity
        self.num_units = num_units
        
        if isinstance(incoming, int):
            self.num_inputs = incoming
        elif isinstance(incoming, (tuple, list)):
            self.num_inputs = int(np.prod(incoming[2:])) if len(incoming) > 2 else incoming[-1]
        else:
            raise ValueError("incoming must be int or shape-like (tuple/list)")
        
        self.backwards = backwards
        self.gradient_steps = gradient_steps
        self.only_return_final = only_return_final
        self._srng = torch.Generator().manual_seed(np.random.randint(1e7))
        self.hidden_noise = torch.ones(1, dtype=torch.float32)
        self.hidden_clip = torch.ones(1, dtype=torch.float32)
        self.mu_hid = torch.ones(1, dtype=torch.float32)
        self.log_sigma2_hid = torch.ones(1, dtype=torch.float32)
        self.learn_init = learn_init
        self.hid_prop = hid_prop

        if ingate is None:
            self.W_in_to_ingate = nn.Parameter(torch.empty(self.num_inputs, self.num_units))
            self.W_hid_to_ingate = nn.Parameter(torch.empty(self.num_units, self.num_units))
            self.b_ingate = nn.Parameter(torch.full((self.num_units,), 0.0))  # Constant(0.)
            nn.init.xavier_uniform_(self.W_in_to_ingate)            # GlorotUniform
            nn.init.orthogonal_(self.W_hid_to_ingate, gain=1.1)     # Orthogonal
            self.nonlinearity_ingate = hard_sigmoid
        
        if forgetgate is None:
            self.W_in_to_forgetgate = nn.Parameter(torch.empty(self.num_inputs, self.num_units))
            self.W_hid_to_forgetgate = nn.Parameter(torch.empty(self.num_units, self.num_units))
            self.b_forgetgate = nn.Parameter(torch.full((self.num_units,), 1.0))  # Constant(1.)
            nn.init.xavier_uniform_(self.W_in_to_forgetgate)
            nn.init.orthogonal_(self.W_hid_to_forgetgate, gain=1.1)
            self.nonlinearity_forgetgate = hard_sigmoid

        if cell is None:
            self.W_in_to_cell = nn.Parameter(torch.empty(self.num_inputs, self.num_units))
            self.W_hid_to_cell = nn.Parameter(torch.empty(self.num_units, self.num_units))
            self.b_cell = nn.Parameter(torch.full((self.num_units,), 0.0))
            nn.init.xavier_uniform_(self.W_in_to_cell)
            nn.init.orthogonal_(self.W_hid_to_cell, gain=1.1)
            self.nonlinearity_cell = torch.tanh

        if outgate is None:
            self.W_in_to_outgate = nn.Parameter(torch.empty(self.num_inputs, self.num_units))
            self.W_hid_to_outgate = nn.Parameter(torch.empty(self.num_units, self.num_units))
            self.b_outgate = nn.Parameter(torch.full((self.num_units,), 0.0))
            nn.init.xavier_uniform_(self.W_in_to_outgate)
            nn.init.orthogonal_(self.W_hid_to_outgate, gain=1.1)
            self.nonlinearity_outgate = hard_sigmoid

        self.hid_init = nn.Parameter(
            torch.full((1, self.num_units), hid_init, dtype=torch.float32),
            requires_grad=learn_init
        )

        self.cell_init = nn.Parameter(
            torch.full((1, self.num_units), cell_init, dtype=torch.float32),
            requires_grad=learn_init
        )
    
    def input_preactivation(self, input: torch.Tensor, gate_type: str, **kwargs) -> torch.Tensor:
        if gate_type == 'input':
            return input @ self.W_in_to_ingate
        elif gate_type == 'forget':
            return input @ self.W_in_to_forgetgate
        elif gate_type == 'cell':
            return input @ self.W_in_to_cell
        elif gate_type == 'output':
            return input @ self.W_in_to_outgate
        else:
            raise ValueError(f"Unknown gate_type: {gate_type}")
    
    def get_output_shape_for(self, input_shape):
        """
        input_shape: tuple, (batch_size, seq_len, input_size)
        """
        batch_size, seq_len = input_shape[0], input_shape[1]

        if self.only_return_final:
            return (batch_size, self.num_units)
        elif self.hid_prop:
            return (2, batch_size, seq_len, self.num_units)
        else:
            return (batch_size, seq_len, self.num_units)
    
    def generate_noise_and_clip(self, num_batch, seq_len, **kwargs):
        return
    
    def get_output_for(self, inputs):
        input = inputs[0]

        mask = None
        if self.mask_incoming_index > 0:
            mask = inputs[self.mask_incoming_index]
        input = input.transpose(0, 1)  # (seq_len, batch, input_size)
        seq_len, num_batch, _ = input.shape
        input_i = self.input_preactivation(input, 'input') + self.b_ingate
        input_f = self.input_preactivation(input, 'forget') + self.b_forgetgate
        input_c = self.input_preactivation(input, 'cell') + self.b_cell
        input_o = self.input_preactivation(input, 'output') + self.b_outgate

        if self.hid_prop:
            hid_init, cell_init = inputs[1][0], inputs[1][1]
        else:
            hid_init = self.hid_init.expand(num_batch, -1)  # (batch, num_units)
            cell_init = self.cell_init.expand(num_batch, -1)

        hid = hid_init
        cell = cell_init
        hid_seq = []
        cell_seq = []

        for t in range(seq_len):
            i = input_i[t]
            f = input_f[t]
            c = input_c[t]
            o = input_o[t]

            ingate = self.nonlinearity_ingate(i + self.hidden_preactivation(hid, 'input'))
            forgetgate = self.nonlinearity_forgetgate(f + self.hidden_preactivation(hid, 'forget'))
            cell = forgetgate * cell + ingate * self.nonlinearity_cell(c + self.hidden_preactivation(hid, 'cell'))
            outgate = self.nonlinearity_outgate(o + self.hidden_preactivation(hid, 'output'))
            hid = outgate * self.nonlinearity(cell)

            if mask is not None:
                m = mask[t].unsqueeze(-1)
                cell = cell * m + cell_init * (1 - m)
                hid = hid * m + hid_init * (1 - m)

            hid_seq.append(hid)
            cell_seq.append(cell)

            hid_out = torch.stack(hid_seq)  # (seq_len, batch, num_units)
            cell_out = torch.stack(cell_seq)

            if self.only_return_final:
                hid_out = hid_out[-1]
            else:
                hid_out = hid_out.transpose(0, 1)  # (batch, seq_len, num_units)
                cell_out = cell_out.transpose(0, 1)

            if self.hid_prop:
                return torch.stack([hid_out.unsqueeze(0), cell_out.unsqueeze(0)])  # (2, batch, seq_len, num_units)
            else:
                return hid_out
    
    def forward(self, inputs, deterministic: bool = False, clip: bool = False, **kwargs):
        """
        PyTorch forward, сохраняет логику оригинального get_output_for.
        inputs: либо тензор (batch, seq_len, input_dim) либо список/tuple, где inputs[0] - вход,
                и при self.mask_incoming_index > 0 mask находится в inputs[self.mask_incoming_index].
        Возвращает:
        - если self.only_return_final: (batch, num_units)
        - elif self.hid_prop: (2, batch, seq_len, num_units)
        - else: (batch, seq_len, num_units)
        """
        # Поддержка вариантов входа (как было в Theano: inputs — список)
        if isinstance(inputs, (list, tuple)):
            input = inputs[0]
        else:
            input = inputs

        mask = None
        if getattr(self, "mask_incoming_index", -1) > 0:
            # mask ожидается в том же списке inputs
            if isinstance(inputs, (list, tuple)) and len(inputs) > self.mask_incoming_index:
                mask = inputs[self.mask_incoming_index]
            else:
                mask = None

        # Переставляем оси, как в Theano: (batch, seq_len, input_dim) -> (seq_len, batch, input_dim)
        input = input.transpose(0, 1)  # (seq_len, batch, input_dim)
        seq_len, num_batch, _ = input.shape

        # Генерация шума/клипов, если нужно (метод должен быть реализован)
        # передаём num_batch и seq_len, а также флаги deterministic/clip для совместимости
        try:
            self.generate_noise_and_clip(num_batch, deterministic, clip)
        except TypeError:
            # если generate_noise_and_clip не ожидает clip/deterministic — вызовем только по num_batch
            self.generate_noise_and_clip(num_batch, seq_len)

        # Предактивации входной части (возвращают (seq_len, batch, num_units))
        input_i = self.input_preactivation(input, 'input', deterministic=deterministic, clip=clip, **kwargs) + self.b_ingate
        input_f = self.input_preactivation(input, 'forget', deterministic=deterministic, clip=clip, **kwargs) + self.b_forgetgate
        input_c = self.input_preactivation(input, 'cell', deterministic=deterministic, clip=clip, **kwargs) + self.b_cell
        input_o = self.input_preactivation(input, 'output', deterministic=deterministic, clip=clip, **kwargs) + self.b_outgate

        # Начальные состояния
        if self.hid_prop:
            # ожидаем, что inputs[1] содержит (2, batch, num_units) или (2, num_batch, num_units)
            hid_init, cell_init = inputs[1][0], inputs[1][1]
        else:
            hid_init = self.hid_init.expand(num_batch, -1).to(input.device, dtype=input.dtype)   # (batch, num_units)
            cell_init = self.cell_init.expand(num_batch, -1).to(input.device, dtype=input.dtype)

        hid = hid_init
        cell = cell_init

        hid_seq = []
        cell_seq = []

        # если есть маска, приведение её к форме (seq_len, batch, 1) для индексации
        if mask is not None:
            # mask может быть (batch, seq_len) или (batch, seq_len, 1)
            if mask.ndim == 3:
                mask_seq = mask.permute(1, 0, 2)  # (seq_len, batch, 1)
            else:
                mask_seq = mask.unsqueeze(-1).permute(1, 0, 2)  # (seq_len, batch, 1)
            mask_seq = mask_seq.to(dtype=input.dtype, device=input.device)
        else:
            mask_seq = None

        # Основной рекуррентный цикл (как в Theano step / step_masked)
        for t in range(seq_len):
            input_n_i = input_i[t]  # (batch, num_units)
            input_n_f = input_f[t]
            input_n_c = input_c[t]
            input_n_o = input_o[t]

            # рекуррентные предактивации от предыдущего hid (должен быть реализован)
            hid_preact_i = self.hidden_preactivation(hid, 'input', **kwargs)
            hid_preact_f = self.hidden_preactivation(hid, 'forget', **kwargs)
            hid_preact_c = self.hidden_preactivation(hid, 'cell', **kwargs)
            hid_preact_o = self.hidden_preactivation(hid, 'output', **kwargs)

            ingate = self.nonlinearity_ingate(input_n_i + hid_preact_i)
            forgetgate = self.nonlinearity_forgetgate(input_n_f + hid_preact_f)
            cell_candidate = self.nonlinearity_cell(input_n_c + hid_preact_c)
            cell = forgetgate * cell + ingate * cell_candidate
            outgate = self.nonlinearity_outgate(input_n_o + hid_preact_o)
            hid = outgate * self.nonlinearity(cell)

            # маскирование (T.switch(mask_n, new, prev) эквивалентно m*new + (1-m)*prev)
            if mask_seq is not None:
                m = mask_seq[t]  # (batch, 1)
                # broadcasting: m * new + (1-m) * previous
                cell = m * cell + (1.0 - m) * cell_init
                hid  = m * hid  + (1.0 - m) * hid_init

            hid_seq.append(hid)
            cell_seq.append(cell)

        # собираем последовательности вне цикла
        cell_out = torch.stack(cell_seq, dim=0)  # (seq_len, batch, num_units)
        hid_out = torch.stack(hid_seq, dim=0)    # (seq_len, batch, num_units)

        # Если only_return_final -> финальное скрытое состояние (последний по времени, в порядке вычисления)
        if self.only_return_final:
            return hid_out[-1]   # (batch, num_units)

        # если вычисляли backwards, нужно вернуть в прямой порядок времени (как в Theano)
        if self.backwards:
            hid_out = hid_out.flip(dims=[0])
            cell_out = cell_out.flip(dims=[0])

        # переставим в (batch, seq_len, num_units)
        hid_out = hid_out.transpose(0, 1)   # (batch, seq_len, num_units)
        cell_out = cell_out.transpose(0, 1)

        if self.hid_prop:
            # вернуть в виде (2, batch, seq_len, num_units)
            return torch.cat([hid_out.unsqueeze(0), cell_out.unsqueeze(0)], dim=0)
        else:
            return hid_out


class BayesianLSTM(LSTM):
    """
    config: L probabilistic weight with lognormal prior, N probabilistic weight with standart normal prior, 
           D deterministic learnable weight, 
           C constant weight (1 for multiplicative and 0 for additive weights)\
           
           config[0]: W input_to_hidden, W hidden_to_hidden
                     L N D (C is not supported)
           config[1]: hat Z preactivation multiplicative weights
                     L N D C
           config[2]: Z input and hidden multiplicative weights
                     L N D C I R
    """
    def __init__(self, 
                 incoming, 
                 num_units,
                 log_sigma_in_init = -3.0, 
                 log_sigma_hid_init = -3.0,
                 ingate=None,
                 forgetgate=None,
                 cell=None,
                 outgate=None,
                 hid_init=0.0,
                 cell_init=0.0,
                 learn_init=True,
                 nonlinearity=torch.tanh,
                 backwards=False,
                 gradient_steps=-1,
                 mask_input=None,
                 only_return_final=False,
                 hid_prop = False,
                 config="DCC",
                 **kwargs):
 
        super().__init__(incoming, 
                         num_units, 
                         ingate, 
                         forgetgate, 
                         cell, 
                         outgate,
                         hid_init, 
                         cell_init, 
                         learn_init, 
                         nonlinearity, 
                         backwards, 
                         gradient_steps, 
                         mask_input,
                         only_return_final,
                         hid_prop,
                         **kwargs)
        
        self.name = 'BayesianLSTM'
        self.reg = True
        self.config = config
        self.log_sigma_in_init = log_sigma_in_init
        self.log_sigma_hid_init = log_sigma_hid_init

        if self.config[0] in {"L", "N"}:
            self.logsig_w_in = nn.Parameter(torch.full((4, incoming, num_units), log_sigma_in_init))
            self.logsig_w_hid = nn.Parameter(torch.full((4, num_units, num_units), log_sigma_hid_init))
        else:
            self.register_buffer("logsig_w_in", torch.zeros(4))
            self.register_buffer("logsig_w_hid", torch.zeros(4))
        
        if self.config[2] in {"L", "N", "D", "I"}:
            self.mu_in = nn.Parameter(torch.ones(incoming))
        if self.config[2] in {"L", "N", "I"}:
            self.logsig_in = nn.Parameter(torch.full((incoming,), log_sigma_in_init))
        if self.config[2] in {"L", "N", "D", "R"}:
            self.mu_hid = nn.Parameter(torch.ones(num_units))
        if self.config[2] in {"L", "N", "R"}:
            self.logsig_hid = nn.Parameter(torch.full((num_units,), log_sigma_hid_init))

        if self.config[1] in {"L", "N", "D"}:
            self.mu_gates = nn.Parameter(torch.ones(4, num_units))
        if self.config[1] in {"L", "N"}:
            self.logsig_gates = nn.Parameter(torch.full((4, num_units), log_sigma_hid_init))

        self.input_noise = None
        self.hidden_noise = None
        self.input_clip = None
        self.hidden_clip = None

        self.thresh = 3.0
    
    def clip_func(self, mtx, to=8):
        return torch.clamp(mtx, min=-to, max=to)
    
    def generate_noise_and_clip(self, num_batch, deterministic=False, clip=False):
        if not deterministic:
            # --- W_in, W_hid noise ---
            if self.config[0] in {"L", "N"}:
                self.input_w_noise = torch.randn(4, self.num_inputs, self.num_units) * torch.exp(self.logsig_w_in)
                self.hidden_w_noise = torch.randn(4, self.num_units, self.num_units) * torch.exp(self.logsig_w_hid)
            else:
                self.input_w_noise = torch.zeros(4)
                self.hidden_w_noise = torch.zeros(4)

            # --- input/hidden noise ---
            if self.config[2] in {"L", "N"}:
                self.input_noise = torch.randn(num_batch, self.num_inputs) * torch.exp(self.logsig_in) + self.mu_in
                self.hidden_noise = torch.randn(num_batch, self.num_units) * torch.exp(self.logsig_hid) + self.mu_hid
            elif self.config[2] == "I":
                self.input_noise = torch.randn((num_batch, self.num_inputs)) * torch.exp(self.logsig_in) + self.mu_in
                self.hidden_noise = torch.ones(1)
            elif self.config[2] == "R":
                self.input_noise = torch.ones(1)
                self.hidden_noise = torch.randn(num_batch, self.num_units) * torch.exp(self.logsig_hid) + self.mu_hid
            elif self.config[2] == "D":
                self.input_noise = self.mu_in
                self.hidden_noise = self.mu_hid
            else:
                self.input_noise = torch.ones(1)
                self.hidden_noise = torch.ones(1)
        
            # --- gates noise ---
            if self.config[1] in {"L", "N"}:
                self.gates_noise = torch.randn(4, num_batch, self.num_units) * torch.exp(self.logsig_gates)[:, None, :] + self.mu_gates[:, None, :]
            elif self.config[1] == "D":
                self.gates_noise = self.mu_gates
            else:
                self.gates_noise = torch.ones(4)
        
        else:
            # deterministic path
            self.input_w_noise = torch.zeros(4)
            self.hidden_w_noise = torch.zeros(4)

            if self.config[2] in {"L", "N", "D"}:
                self.input_noise = self.mu_in
                self.hidden_noise = self.mu_hid
            elif self.config[2] == "I":
                self.input_noise = self.mu_in
                self.hidden_noise = torch.ones(1)
            elif self.config[2] == "R":
                self.input_noise = torch.ones(1)
                self.hidden_noise = self.mu_hid
            else:
                self.input_noise = torch.ones(1)
                self.hidden_noise = torch.ones(1)

            if self.config[1] in {"L", "N", "D"}:
                self.gates_noise = self.mu_gates
            else:
                self.gates_noise = torch.ones(4)
        
        if clip:
            if self.config[0] == "L":
                W_in_cat = torch.cat([self.W_in_to_ingate[None,:,:],
                                    self.W_in_to_forgetgate[None,:,:],
                                    self.W_in_to_cell[None,:,:],
                                    self.W_in_to_outgate[None,:,:]], dim=0)
                log_alpha_w_in = self.clip_func(2*self.logsig_w_in - torch.log(W_in_cat**2))
                self.input_w_clip = log_alpha_w_in <= self.thresh

                W_hid_cat = torch.cat([self.W_hid_to_ingate[None,:,:],
                                    self.W_hid_to_forgetgate[None,:,:],
                                    self.W_hid_to_cell[None,:,:],
                                    self.W_hid_to_outgate[None,:,:]], dim=0)
                log_alpha_w_hid = self.clip_func(2*self.logsig_w_hid - torch.log(W_hid_cat**2))
                self.hidden_w_clip = log_alpha_w_hid <= self.thresh
            else:
                self.input_w_clip = torch.ones(4)
                self.hidden_w_clip = torch.ones(4)

            if self.config[2] == "L":
                log_alpha_in = self.clip_func(2*self.logsig_in - torch.log(self.mu_in**2))
                self.input_clip = log_alpha_in <= self.thresh

                log_alpha_hid = self.clip_func(2*self.logsig_hid - torch.log(self.mu_hid**2))
                self.hidden_clip = log_alpha_hid <= self.thresh
            elif self.config[2] == "I":
                log_alpha_in = self.clip_func(2*self.logsig_in - torch.log(self.mu_in**2))
                self.input_clip = log_alpha_in <= self.thresh
                self.hidden_clip = torch.ones(1)
            elif self.config[2] == "R":
                self.input_clip = torch.ones(1)
                log_alpha_hid = self.clip_func(2*self.logsig_hid - torch.log(self.mu_hid**2))
                self.hidden_clip = log_alpha_hid <= self.thresh
            else:
                self.input_clip = torch.ones(1)
                self.hidden_clip = torch.ones(1)

            if self.config[1] == "L":
                log_alpha_gates = self.clip_func(2*self.logsig_gates - torch.log(self.mu_gates**2))
                self.gates_clip = log_alpha_gates <= self.thresh
            else:
                self.gates_clip = torch.ones(4)
        
        else:
            self.input_w_clip = torch.ones(4)
            self.hidden_w_clip = torch.ones(4)
            self.input_clip = torch.ones(1)
            self.hidden_clip = torch.ones(1)
            self.gates_clip = torch.ones(4)

        return
    
    def input_preactivation(self, input, gate_type, deterministic = False, clip = False):

        if gate_type == "input":
            W, idx = self.W_in_to_ingate, 0
        elif gate_type == "forget":
            W, idx = self.W_in_to_forgetgate, 1
        elif gate_type == "cell":
            W, idx = self.W_in_to_cell, 2
        elif gate_type == "output":
            W, idx = self.W_in_to_outgate, 3
        else:
            raise ValueError(f"Unknown gate_type {gate_type}")
        
        input = input * self.input_noise * self.input_clip
        W_eff = (W + self.input_w_noise[idx]) * self.input_w_clip[idx]
        return torch.matmul(input, W_eff)
    
    def hidden_preactivation(self, hidden, gate_type, deterministic = False, clip = False):
        if gate_type == "input":
            W, idx = self.W_hid_to_ingate, 0
        elif gate_type == "forget":
            W, idx = self.W_hid_to_forgetgate, 1
        elif gate_type == "cell":
            W, idx = self.W_hid_to_cell, 2
        elif gate_type == "output":
            W, idx = self.W_hid_to_outgate, 3
        else:
            raise ValueError(f"Unknown gate_type {gate_type}")
        
        W_eff = (W + self.hidden_w_noise[idx]) * self.hidden_w_clip[idx]
        return torch.matmul(hidden, W_eff)
    
    def get_output_for(self, inputs, deterministic=False, clip=False, **kwargs):
        input = inputs[0]                    # (batch, seq_len, input_dim)
        mask = None
        if getattr(self, "mask_incoming_index", -1) > 0:
            mask = inputs[self.mask_incoming_index]  # ожидаем (batch, seq_len) или (batch, seq_len, 1)

        input = input.permute(1, 0, 2)
        seq_len = input.shape[0]
        num_batch = input.shape[1]
        dtype = input.dtype

        self.generate_noise_and_clip(num_batch, deterministic, clip)

        input_i = self.input_preactivation(input, 'input', deterministic=deterministic, clip=clip, **kwargs)
        input_f = self.input_preactivation(input, 'forget', deterministic=deterministic, clip=clip, **kwargs)
        input_c = self.input_preactivation(input, 'cell', deterministic=deterministic, clip=clip, **kwargs)
        input_o = self.input_preactivation(input, 'output', deterministic=deterministic, clip=clip, **kwargs)

        if self.hid_prop:
            hid_init = inputs[1][0, :, :]   # (batch, num_units) expected
            cell_init = inputs[1][1, :, :]
        else:
            # self.hid_init и cell_init — в форме (1, num_units) как в Theano
            hid_init = self.hid_init.expand(num_batch, -1).to(dtype=dtype)
            cell_init = self.cell_init.expand(num_batch, -1).to(dtype=dtype)

        # def _as_float(t):
        #     if t is None:
        #         return None
        #     if t.dtype == torch.bool:
        #         return t.to(dtype=dtype)
        #     return t.to(dtype=dtype)

        # gates_noise = _as_float(getattr(self, "gates_noise", None))
        # gates_clip = _as_float(getattr(self, "gates_clip", torch.ones(4, dtype=dtype)))
        # hidden_noise = _as_float(getattr(self, "hidden_noise", torch.ones(1, dtype=dtype)))
        # hidden_clip = _as_float(getattr(self, "hidden_clip", torch.ones(1, dtype=dtype)))

        hid = hid_init
        cell = cell_init

        hid_seq = []
        cell_seq = []

        # порядок обхода (если self.backwards True, мы обойдём в обратном порядке,
        # затем при возврате приведём к прямому порядку — как в оригинальном коде)
        t_range = range(seq_len - 1, -1, -1) if self.backwards else range(seq_len)

        for t in t_range:
            # входные предактивации на текущем шаге: формы (batch, num_units)
            input_n_i = input_i[t]
            input_n_f = input_f[t]
            input_n_c = input_c[t]
            input_n_o = input_o[t]

            # рекуррентные предактивации: hidden_preactivation(hid_previous, '...') -> (batch, num_units)
            hid_preact_i = self.hidden_preactivation(hid, 'input', **kwargs)
            hid_preact_f = self.hidden_preactivation(hid, 'forget', **kwargs)
            hid_preact_c = self.hidden_preactivation(hid, 'cell', **kwargs)
            hid_preact_o = self.hidden_preactivation(hid, 'output', **kwargs)

            # Для совместимости: gates_noise[gate] может быть shape (num_batch, num_units) или (num_units,)
            g0 = self.gates_noise[0] if self.gates_noise is not None else torch.ones_like(hid_preact_i, dtype=dtype)
            g1 = self.gates_noise[1] if self.gates_noise is not None else torch.ones_like(hid_preact_i, dtype=dtype)
            g2 = self.gates_noise[2] if self.gates_noise is not None else torch.ones_like(hid_preact_i, dtype=dtype)
            g3 = self.gates_noise[3] if self.gates_noise is not None else torch.ones_like(hid_preact_i, dtype=dtype)

            gc0 = self.gates_clip[0] if self.gates_clip is not None else torch.ones(1, dtype=dtype)
            gc1 = self.gates_clip[1] if self.gates_clip is not None else torch.ones(1, dtype=dtype)
            gc2 = self.gates_clip[2] if self.gates_clip is not None else torch.ones(1, dtype=dtype)
            gc3 = self.gates_clip[3] if self.gates_clip is not None else torch.ones(1, dtype=dtype)

            # Внимание: gc* может иметь форму (num_units,) или (1,), поэтому приводим к dtype и позволяем broadcasting
            gc0 = gc0.to(dtype=dtype)
            gc1 = gc1.to(dtype=dtype)
            gc2 = gc2.to(dtype=dtype)
            gc3 = gc3.to(dtype=dtype)

            # b_* ожидаются как (num_units,), приводим к dtype
            b_ing = getattr(self, "b_ingate").to(dtype=dtype)
            b_forg = getattr(self, "b_forgetgate").to(dtype=dtype)
            b_cell = getattr(self, "b_cell").to(dtype=dtype)
            b_out = getattr(self, "b_outgate").to(dtype=dtype)

            # вычисляем гейты точно как в Theano:
            ingate = self.nonlinearity_ingate((input_n_i + hid_preact_i) * g0 * gc0 + b_ing)
            forgetgate = self.nonlinearity_forgetgate((input_n_f + hid_preact_f) * g1 * gc1 + b_forg)
            cell_candidate = self.nonlinearity_cell((input_n_c + hid_preact_c) * g2 * gc2 + b_cell)
            cell = forgetgate * cell + ingate * cell_candidate
            outgate = self.nonlinearity_outgate((input_n_o + hid_preact_o) * g3 * gc3 + b_out)

            hid = outgate * self.nonlinearity(cell)
            # применение шума/клипа к скрытому
            hn = self.hidden_noise if self.hidden_noise is not None else torch.ones(1, dtype=dtype)
            hc = self.hidden_clip if self.hidden_clip is not None else torch.ones(1, dtype=dtype)
            hid = hid * hn * hc

            # если есть маска, обновляем: cell = mask * cell + (1-mask) * cell_previous
            if mask is not None:
                # ожидаем mask формы (batch, seq_len) или (batch, seq_len, 1)
                # приводим к (seq_len, batch, 1) чтобы индексировать по t
                if mask.ndim == 3:
                    mask_seq = mask.permute(1, 0, 2)  # (seq_len, batch, 1)
                else:
                    mask_seq = mask.unsqueeze(-1).permute(1, 0, 2)  # (seq_len, batch, 1)

                m = mask_seq[t].to(dtype=dtype)  # (batch, 1)
                # T.switch(mask_n, cell, cell_previous) <=> m*cell + (1-m)*cell_previous
                cell = m * cell + (1.0 - m) * cell
                hid = m * hid + (1.0 - m) * hid

            # сохраняем текущие состояния
            cell_seq.append(cell)
            hid_seq.append(hid)

        # собираем последовательности (seq_len, batch, num_units)
        cell_out = torch.stack(cell_seq, dim=0)
        hid_out = torch.stack(hid_seq, dim=0)

        # Если пользовался theano.scan с go_backwards=True, hid_out сейчас в том же порядке, в котором мы вычисляли.
        # Theano-оригинал брал hid_out[-1] для only_return_final (это финальное состояние),
        # а для полного вывода он делал dimshuffle(1,0,2) и затем, если backwards, разворачивал по времени.
        if self.only_return_final:
            # финальное состояние (batch, num_units)
            return hid_out[-1]

        # если нужно привести к (batch, seq_len, num_units), и восстановить прямой порядок времени:
        if self.backwards:
            # переворачиваем по оси времени, чтобы вернуть прямой порядок
            hid_out = hid_out.flip(dims=[0])
            cell_out = cell_out.flip(dims=[0])

        hid_out = hid_out.permute(1, 0, 2)   # (batch, seq_len, num_units)
        cell_out = cell_out.permute(1, 0, 2)

        if self.hid_prop:
            # вернуть в форме (2, batch, seq_len, num_units)
            return torch.cat([hid_out.unsqueeze(0), cell_out.unsqueeze(0)], dim=0)
        else:
            return hid_out
    
    def eval_reg(self, train_size):
        W_in = torch.cat([
            self.W_in_to_ingate.unsqueeze(0),
            self.W_in_to_forgetgate.unsqueeze(0),
            self.W_in_to_cell.unsqueeze(0),
            self.W_in_to_outgate.unsqueeze(0)
        ], dim=0)

        if self.config[0] == "N":
            KL_element_in = -self.logsig_w_in + 0.5 * (torch.exp(2 * self.logsig_w_in) + W_in**2) - 0.5
            KL = KL_element_in.sum()
        elif self.config[0] == "L":
            log_alpha_w_in = self.clip_func(2 * self.logsig_w_in - torch.log(W_in**2))
            KL = alpha_regf(log_alpha_w_in).sum()
        else:
            KL = torch.zeros(1, dtype=self.logsig_w_in.dtype, device=self.logsig_w_in.device).sum()

        # Скрытые веса
        W_hid = torch.cat([
            self.W_hid_to_ingate.unsqueeze(0),
            self.W_hid_to_forgetgate.unsqueeze(0),
            self.W_hid_to_cell.unsqueeze(0),
            self.W_hid_to_outgate.unsqueeze(0)
        ], dim=0)

        if self.config[0] == "N":
            KL_element_hid = -self.logsig_w_hid + 0.5 * (torch.exp(2 * self.logsig_w_hid) + W_hid**2) - 0.5
            KL += KL_element_hid.sum()
        elif self.config[0] == "L":
            log_alpha_w_hid = self.clip_func(2 * self.logsig_w_hid - torch.log(W_hid**2))
            KL += alpha_regf(log_alpha_w_hid).sum()

        # Нейроны
        if self.config[2] == "L":
            log_alpha_hid = self.clip_func(2 * self.logsig_hid - torch.log(self.mu_hid**2))
            KL += alpha_regf(log_alpha_hid).sum()
            log_alpha_in = self.clip_func(2 * self.logsig_in - torch.log(self.mu_in**2))
            KL += alpha_regf(log_alpha_in).sum()
        elif self.config[2] == "I":
            log_alpha_in = self.clip_func(2 * self.logsig_in - torch.log(self.mu_in**2))
            KL += alpha_regf(log_alpha_in).sum()
        elif self.config[2] == "R":
            log_alpha_hid = self.clip_func(2 * self.logsig_hid - torch.log(self.mu_hid**2))
            KL += alpha_regf(log_alpha_hid).sum()
        elif self.config[2] == "N":
            KL_element = -self.logsig_hid + 0.5 * (torch.exp(2 * self.logsig_hid) + self.mu_hid**2) - 0.5
            KL += KL_element.sum()
            KL_element = -self.logsig_in + 0.5 * (torch.exp(2 * self.logsig_in) + self.mu_in**2) - 0.5
            KL += KL_element.sum()

        # Гейты
        if self.config[1] == "L":
            log_alpha_gates = self.clip_func(2 * self.logsig_gates - torch.log(self.mu_gates**2))
            KL += alpha_regf(log_alpha_gates).sum()
        elif self.config[1] == "N":
            KL_element = -self.logsig_gates + 0.5 * (torch.exp(2 * self.logsig_gates) + self.mu_gates**2) - 0.5
            KL += KL_element.sum()

        return KL / train_size
    
    def get_ard(self):
        # --- W ---
        if self.config[0] == "L":
            W_in = torch.cat([
                self.W_in_to_ingate.unsqueeze(0),
                self.W_in_to_forgetgate.unsqueeze(0),
                self.W_in_to_cell.unsqueeze(0),
                self.W_in_to_outgate.unsqueeze(0)
            ], dim=0)
            log_alpha_w_in = 2 * self.logsig_w_in - 2 * torch.log(torch.abs(W_in) + 1e-8)
            mask_w_in = log_alpha_w_in < self.thresh

            W_hid = torch.cat([
                self.W_hid_to_ingate.unsqueeze(0),
                self.W_hid_to_forgetgate.unsqueeze(0),
                self.W_hid_to_cell.unsqueeze(0),
                self.W_hid_to_outgate.unsqueeze(0)
            ], dim=0)
            log_alpha_w_hid = 2 * self.logsig_w_hid - 2 * torch.log(torch.abs(W_hid) + 1e-8)
            mask_w_hid = log_alpha_w_hid < self.thresh
        else:
            mask_w_in = torch.ones((4,) + self.W_in_to_ingate.shape, dtype=torch.bool, device=self.W_in_to_ingate.device)
            mask_w_hid = torch.ones((4,) + self.W_hid_to_ingate.shape, dtype=torch.bool, device=self.W_hid_to_ingate.device)

        # --- neurons ---
        mask_in = mask_w_in.any(dim=2).any(dim=0)
        mask_hid_by_w = mask_w_hid.any(dim=2).any(dim=0)
        mask_hid_by_z = torch.ones_like(mask_hid_by_w, dtype=torch.bool)

        if self.config[2] == "L":
            log_alpha_hid = 2 * self.logsig_hid - 2 * torch.log(torch.abs(self.mu_hid) + 1e-8)
            log_alpha_in = 2 * self.logsig_in - 2 * torch.log(torch.abs(self.mu_in) + 1e-8)
            mask_in = torch.logical_and(log_alpha_in < self.thresh, mask_in)
            mask_hid_by_z = log_alpha_hid < self.thresh
        elif self.config[2] == "I":
            log_alpha_in = 2 * self.logsig_in - 2 * torch.log(torch.abs(self.mu_in) + 1e-8)
            mask_in = torch.logical_and(log_alpha_in < self.thresh, mask_in)
        elif self.config[2] == "R":
            log_alpha_hid = 2 * self.logsig_hid - 2 * torch.log(torch.abs(self.mu_hid) + 1e-8)
            mask_hid_by_z = log_alpha_hid < self.thresh

        # --- gates ---
        mask = torch.cat([mask_w_in, mask_w_hid], dim=1)
        if self.config[1] == "L":
            log_alpha_gates = 2 * self.logsig_gates - 2 * torch.log(torch.abs(self.mu_gates) + 1e-8)
            mask_gates = torch.logical_and(log_alpha_gates < self.thresh, mask.any(dim=1))
        else:
            mask_gates = mask.any(dim=1)

        return {
            "w_input": mask_w_in,
            "w_hidden": mask_w_hid,
            "gates": mask_gates,
            "z_input": mask_in,
            "z_hidden_by_w": mask_hid_by_w,
            "z_hidden": mask_hid_by_z,
        }
    
    def forward(self, inputs, hid_init=None, deterministic: bool = False, clip: bool = False, **kwargs):
        """
        PyTorch forward for BayesianLSTM — повторяет логику get_output_for.
        inputs: либо тензор (batch, seq_len, input_dim) либо список/tuple:
                inputs[0] - input tensor,
                при self.mask_incoming_index > 0 mask ожидается в inputs[self.mask_incoming_index],
                при self.hid_prop ожидается inputs[1] с hid_init и cell_init.
        Возвращает:
        - если self.only_return_final: (batch, num_units)
        - elif self.hid_prop: (2, batch, seq_len, num_units)
        - else: (batch, seq_len, num_units)
        """
        # --- извлекаем input и mask как в оригинале ---
        if isinstance(inputs, (list, tuple)):
            x = inputs[0]
        else:
            x = inputs

        mask = None
        if getattr(self, "mask_incoming_index", -1) > 0 and isinstance(inputs, (list, tuple)):
            # защитимся от выхода за пределы
            if len(inputs) > self.mask_incoming_index:
                mask = inputs[self.mask_incoming_index]

        # ожидаем вход (batch, seq_len, input_dim) -> переставляем (seq_len, batch, input_dim)
        x = x.permute(1, 0, 2)
        seq_len, num_batch, _ = x.shape
        device = x.device
        dtype = x.dtype

        # --- подготовка шума/клип-масок (перенесём результаты на нужное device/dtype) ---
        self.generate_noise_and_clip(num_batch, deterministic, clip)

        # переместим созданные поля на устройство и приведём типы (если они существуют)
        def _to(t):
            if t is None:
                return None
            try:
                return t.to(device=device, dtype=dtype)
            except Exception:
                # если это Python scalar/1-dim like, попытка через torch.tensor
                return torch.tensor(t, device=device, dtype=dtype)

        # входной/скрытый шум и клип-маски
        self.input_w_noise = _to(getattr(self, "input_w_noise", None))
        self.hidden_w_noise = _to(getattr(self, "hidden_w_noise", None))
        self.input_noise = _to(getattr(self, "input_noise", None))
        self.hidden_noise = _to(getattr(self, "hidden_noise", None))
        self.input_w_clip = _to(getattr(self, "input_w_clip", None))
        self.hidden_w_clip = _to(getattr(self, "hidden_w_clip", None))
        self.input_clip = _to(getattr(self, "input_clip", None))
        self.hidden_clip = _to(getattr(self, "hidden_clip", None))
        self.gates_noise = _to(getattr(self, "gates_noise", None))
        self.gates_clip = _to(getattr(self, "gates_clip", None))

        # --- предактивации входной части (seq_len, batch, num_units) ---
        input_i = self.input_preactivation(x, 'input', deterministic=deterministic, clip=clip, **kwargs) + self.b_ingate
        input_f = self.input_preactivation(x, 'forget', deterministic=deterministic, clip=clip, **kwargs) + self.b_forgetgate
        input_c = self.input_preactivation(x, 'cell', deterministic=deterministic, clip=clip, **kwargs) + self.b_cell
        input_o = self.input_preactivation(x, 'output', deterministic=deterministic, clip=clip, **kwargs) + self.b_outgate

        # --- начальные состояния ---
        # if self.hid_prop:
        #     hid_init = inputs[1][0, :, :].to(device=device, dtype=dtype)
        #     cell_init = inputs[1][1, :, :].to(device=device, dtype=dtype)
        # else:
        #     hid_init = self.hid_init.expand(num_batch, -1).to(device=device, dtype=dtype)
        #     cell_init = self.cell_init.expand(num_batch, -1).to(device=device, dtype=dtype)
        
        if self.hid_prop and hid_init is not None:
            hid = hid_init[0].to(device=device, dtype=dtype)
            cell = hid_init[1].to(device=device, dtype=dtype)
        else:
            hid = None
            cell = None
        # hid = hid_init
        # cell = cell_init

        hid_seq = []
        cell_seq = []

        # перебор по времени (учёт backwards)
        t_range = range(seq_len - 1, -1, -1) if self.backwards else range(seq_len)

        for t in t_range:
            # предактивации для текущего шага (batch, num_units)
            input_n_i = input_i[t]
            input_n_f = input_f[t]
            input_n_c = input_c[t]
            input_n_o = input_o[t]

            # рекуррентные предактивации
            hid_preact_i = self.hidden_preactivation(hid, 'input', deterministic=deterministic, clip=clip, **kwargs)
            hid_preact_f = self.hidden_preactivation(hid, 'forget', deterministic=deterministic, clip=clip, **kwargs)
            hid_preact_c = self.hidden_preactivation(hid, 'cell', deterministic=deterministic, clip=clip, **kwargs)
            hid_preact_o = self.hidden_preactivation(hid, 'output', deterministic=deterministic, clip=clip, **kwargs)

            # gates_noise может иметь форму (4, num_batch, num_units) или (4, num_units) или (4,)
            # приведём g* к форме (batch, num_units) через broadcast
            if self.gates_noise is not None:
                g0 = self.gates_noise[0]
                g1 = self.gates_noise[1]
                g2 = self.gates_noise[2]
                g3 = self.gates_noise[3]
                # если нужно, расширим dim для batch
                if g0.ndim == 1:
                    g0 = g0.unsqueeze(0).expand(num_batch, -1)
                    g1 = g1.unsqueeze(0).expand(num_batch, -1)
                    g2 = g2.unsqueeze(0).expand(num_batch, -1)
                    g3 = g3.unsqueeze(0).expand(num_batch, -1)
                elif g0.ndim == 2 and g0.shape[0] == num_batch:
                    pass  # уже (batch, units)
                else:
                    # если gates_noise имелось в форме (4, batch, units), индексирование уже верно
                    g0 = g0 if g0.ndim == 2 else g0.to(device=device, dtype=dtype)
                    g1 = g1 if g1.ndim == 2 else g1.to(device=device, dtype=dtype)
                    g2 = g2 if g2.ndim == 2 else g2.to(device=device, dtype=dtype)
                    g3 = g3 if g3.ndim == 2 else g3.to(device=device, dtype=dtype)
            else:
                g0 = g1 = g2 = g3 = torch.ones((num_batch, self.num_units), device=device, dtype=dtype)

            # gates_clip can be (4, num_units) or (4,) or tensor
            def _gclip(idx):
                if self.gates_clip is None:
                    return torch.ones((self.num_units,), device=device, dtype=dtype)
                v = self.gates_clip[idx]
                if v.ndim == 0:
                    return v.expand(self.num_units).to(device=device, dtype=dtype)
                return v.to(device=device, dtype=dtype)
            gc0 = _gclip(0)
            gc1 = _gclip(1)
            gc2 = _gclip(2)
            gc3 = _gclip(3)

            # biases
            b_ing = self.b_ingate.to(device=device, dtype=dtype)
            b_forg = self.b_forgetgate.to(device=device, dtype=dtype)
            b_cell = self.b_cell.to(device=device, dtype=dtype)
            b_out = self.b_outgate.to(device=device, dtype=dtype)

            # вычисление гейтов согласно оригиналу
            ingate = self.nonlinearity_ingate((input_n_i + hid_preact_i) * g0 * gc0 + b_ing)
            forgetgate = self.nonlinearity_forgetgate((input_n_f + hid_preact_f) * g1 * gc1 + b_forg)
            cell_candidate = self.nonlinearity_cell((input_n_c + hid_preact_c) * g2 * gc2 + b_cell)
            cell = forgetgate * cell + ingate * cell_candidate
            outgate = self.nonlinearity_outgate((input_n_o + hid_preact_o) * g3 * gc3 + b_out)

            hid = outgate * self.nonlinearity(cell)

            # применение шума/клипа к скрытому
            hn = self.hidden_noise if self.hidden_noise is not None else torch.ones(1, device=device, dtype=dtype)
            hc = self.hidden_clip if self.hidden_clip is not None else torch.ones(1, device=device, dtype=dtype)
            hid = hid * hn * hc

            # маскирование, если есть mask
            if mask is not None:
                if mask.ndim == 3:
                    mask_seq = mask.permute(1, 0, 2)  # (seq_len, batch, 1)
                else:
                    mask_seq = mask.unsqueeze(-1).permute(1, 0, 2)
                m = mask_seq[t].to(device=device, dtype=dtype)  # (batch, 1)
                # T.switch(mask_n, cell, cell_previous) <=> m*cell + (1-m)*cell_previous
                cell = m * cell + (1.0 - m) * cell
                hid = m * hid + (1.0 - m) * hid

            hid_seq.append(hid)
            cell_seq.append(cell)

        # собираем последовательности (seq_len, batch, num_units)
        cell_out = torch.stack(cell_seq, dim=0)
        hid_out = torch.stack(hid_seq, dim=0)

        # only_return_final
        if self.only_return_final:
            return hid_out[-1]

        # восстановление порядка времени, если нужно
        if self.backwards:
            hid_out = hid_out.flip(dims=[0])
            cell_out = cell_out.flip(dims=[0])

        # в (batch, seq_len, num_units)
        hid_out = hid_out.permute(1, 0, 2)
        cell_out = cell_out.permute(1, 0, 2)

        if self.hid_prop:
            return torch.cat([hid_out.unsqueeze(0), cell_out.unsqueeze(0)], dim=0)
        else:
            return hid_out

# %%
class Dense(nn.Module):
    def __init__(self, incoming, num_units, nonlinearity=nn.Identity()):
        super(Dense, self).__init__()
        self.num_units = num_units
        self.nonlinearity = nonlinearity
        
        self.W = nn.Parameter(torch.empty(incoming, num_units))
        self.b = nn.Parameter(torch.zeros(num_units))
        
        nn.init.xavier_uniform_(self.W)

    def pre_activation(self, input):
        return torch.matmul(input, self.W)
    
    def get_output_shape_for(self, input_shape):
        return tuple(input_shape[:-1]) + (self.num_units,)

    def get_output_for(self, input, **kwargs):
        return self.nonlinearity(self.pre_activation(input, **kwargs) + self.b)

    def get_ard(self):
        return {"w": torch.ones_like(self.W)}
    
    def forward(self, input, **kwargs):
        """
        input: tensor with last dim == incoming, arbitrary leading dims allowed
        returns: tensor with same leading dims and last dim == num_units
        """
        # pre-activation: (..., incoming) @ (incoming, num_units) -> (..., num_units)
        lin = self.pre_activation(input)
        # add bias (1D) -> broadcasting over leading dims
        lin = lin + self.b
        # apply nonlinearity (can be nn.Module or a callable)
        return self.nonlinearity(lin)

class BayesianDense(Dense):
    def __init__(self, 
                 incoming, 
                 num_units, 
                 log_sigma_init = -3.0,
                 W_initializer=None, 
                 b_init=0.0, 
                 nonlinearity=lambda x: x, 
                 **kwargs):
        super().__init__(incoming, num_units, W_initializer, b_init, nonlinearity, **kwargs)

        if isinstance(incoming, int):
            self.num_inputs = int(incoming)
        else:
            try:
                self.num_inputs = int(incoming[-1])
            except Exception:
                raise ValueError("incoming must be int or shape-like")

        self.num_units = int(num_units)
        self.nonlinearity = nonlinearity
        self.name = 'DenseSparseVDO'
        self.thresh = 3.0

        # веса и bias (аналог add_param)
        self.W = nn.Parameter(torch.empty(self.num_inputs, self.num_units, dtype=torch.float32))
        self.b = nn.Parameter(torch.full((self.num_units,), float(b_init), dtype=torch.float32))
        # log_sigma (trainable)
        self.log_sigma = nn.Parameter(torch.full((self.num_inputs, self.num_units), float(log_sigma_init), dtype=torch.float32))

        # инициализация W (GlorotUniform по умолчанию)
        if W_initializer is None:
            nn.init.xavier_uniform_(self.W)
        else:
            # попытаться применить инициализатор
            try:
                W_initializer(self.W)
            except Exception:
                # если инициализатор возвращает numpy
                self.W.data.copy_(torch.tensor(W_initializer(self.W.shape), dtype=self.W.dtype))

        # генератор случайных чисел (аналог RandomStreams)
        seed = np.random.randint(int(1e7))
        self._srng = torch.Generator()
        self._srng.manual_seed(int(seed))

    def clip_func(self, mtx: torch.Tensor, to: float = 8.0) -> torch.Tensor:
        return torch.clamp(mtx, min=-float(to), max=float(to))

    def pre_activation(self, input: torch.Tensor, deterministic: bool = False, clip: bool = False):
        """
        input: либо 2D (batch, input_dim) либо 3D (batch, seq_len, input_dim)
        Возвращает: mu + шум*si (или только mu в deterministic режиме)
        Сохраняет логику оригинала (шум shape для 3D -> (batch,1,num_units))
        """
        device = self.W.device
        dtype = self.W.dtype
        eps = 1e-8

        if deterministic:
            if clip:
                # log_alpha = clip_func(2*self.log_sigma - log(self.W ** 2))
                log_alpha = self.clip_func(2.0 * self.log_sigma - torch.log(self.W.pow(2) + eps))
                clip_mask = log_alpha.ge(self.thresh)  # True где нужно обрезать
                W_eff = torch.where(clip_mask, torch.zeros_like(self.W), self.W)
                return torch.matmul(input, W_eff)
            else:
                return torch.matmul(input, self.W)

        # стохастический режим
        W = self.W
        sigma2 = torch.exp(2.0 * self.log_sigma)

        if clip:
            log_alpha = self.clip_func(2.0 * self.log_sigma - torch.log(self.W.pow(2) + eps))
            clip_mask = log_alpha.ge(self.thresh)
            W = torch.where(clip_mask, torch.zeros_like(self.W), self.W)
            # зануляем sigma2 для обрезанных весов (как в Theano)
            sigma2 = torch.where(clip_mask, torch.zeros_like(sigma2), sigma2)

        # mu = input @ W
        mu = torch.matmul(input, W)  # broadcasting работает для 2D/3D: (..., in) @ (in, out) -> (..., out)

        # si = sqrt( (input*input) @ sigma2 + eps )
        si = torch.sqrt(torch.matmul(input * input, sigma2) + eps)  # shape matches mu

        # создаём шум как в Theano:
        if input.ndim == 2:
            # input shape (batch, in) -> mu shape (batch, out)
            noise = torch.randn(mu.shape, generator=self._srng, device=device, dtype=dtype)
            return mu + noise * si
        else:
            # input shape (batch, seq_len, in) -> mu shape (batch, seq_len, out)
            # Theano генерировал noise shape (batch, 1, out) — один шум на все временные шаги
            noise = torch.randn((mu.shape[0], 1, mu.shape[2]), generator=self._srng, device=device, dtype=dtype)
            return mu + noise * si

    def eval_reg(self, train_size: float):
        """
        alpha regularization: alpha_regf(clip_func(2*log_sigma - log(W^2))).sum() / train_size
        Возвращаем torch scalar
        """
        eps = 1e-8
        log_alpha = self.clip_func(2.0 * self.log_sigma - torch.log(self.W.pow(2) + eps))
        return alpha_regf(log_alpha).sum() / float(train_size)

    def get_ard(self):
        """
        Возвращаем numpy маску (как в оригинале) w: log_alpha < thresh
        оригинал использовал get_value() -> numpy; здесь делаем аналог
        """
        eps = 1e-8
        W_np = self.W.detach().cpu().numpy()
        logsigma_np = self.log_sigma.detach().cpu().numpy()
        log_alpha = 2.0 * logsigma_np - 2.0 * np.log(np.abs(W_np) + eps)
        return {"w": (log_alpha < self.thresh)}
    
    def forward(self, input: torch.Tensor, deterministic: bool = False, clip: bool = False, **kwargs):
        """
        input: tensor with last dim == num_inputs, can be 2D (batch, in) or 3D (batch, seq_len, in)
        deterministic, clip: передаются в pre_activation и управляют режимом (как в Theano-оригинале)
        Возвращает: nonlinearity( pre_activation(input, deterministic, clip) + b )
        """
        # pre_activation вернёт mu + noise*si (или просто mu в deterministic режиме)
        out = self.pre_activation(input, deterministic=deterministic, clip=clip)

        # прибавляем bias; bias shape (num_units,) автоматически broadcast'ится по всем leading dims
        out = out + self.b

        # применяем nonlinearity — может быть nn.Module или простая функция
        return self.nonlinearity(out)


class BayesianDense_noLRT(Dense):
    def __init__(self, incoming, num_units, log_sigma_init=-3.0,
                 W_initializer=None, b_init=0.0, nonlinearity=lambda x: x, **kwargs):
        """
        incoming: int (input size) or shape-like with last dim = input size.
        """
        super().__init__(incoming, num_units, W_initializer, b_init, nonlinearity, **kwargs)
        # определить num_inputs как в Dense
        if isinstance(incoming, int):
            self.num_inputs = int(incoming)
        else:
            try:
                self.num_inputs = int(incoming[-1])
            except Exception:
                raise ValueError("incoming must be int or shape-like")

        self.num_units = int(num_units)
        self.nonlinearity = nonlinearity
        self.name = 'DenseSparseVDO'
        self.thresh = 3.0

        # параметры: W, b, log_sigma
        self.W = nn.Parameter(torch.empty(self.num_inputs, self.num_units, dtype=torch.float32))
        self.b = nn.Parameter(torch.full((self.num_units,), float(b_init), dtype=torch.float32))
        self.log_sigma = nn.Parameter(torch.full((self.num_inputs, self.num_units), float(log_sigma_init), dtype=torch.float32))

        # инициализация весов (GlorotUniform ≈ xavier_uniform)
        if W_initializer is None:
            nn.init.xavier_uniform_(self.W)
        else:
            try:
                W_initializer(self.W)
            except Exception:
                self.W.data.copy_(torch.tensor(W_initializer(self.W.shape), dtype=self.W.dtype))

        # генератор для повторяемых нормальных выборок (аналог RandomStreams)
        seed = np.random.randint(int(1e7))
        self._srng = torch.Generator()
        self._srng.manual_seed(int(seed))

    def clip_func(self, mtx: torch.Tensor, to: float = 8.0) -> torch.Tensor:
        # Эквивалент последовательным T.switch: ограничение в диапазоне [-to, to]
        return torch.clamp(mtx, min=-float(to), max=float(to))

    def pre_activation(self, input: torch.Tensor, deterministic: bool = False, clip: bool = False):
        """
        input: 2D (batch, in) или 3D (batch, seq_len, in) (и др. формы с последним измерением in)
        Ведёт себя как оригинал Theano-кода (с исправлением очевидных опечаток в использовании clip_train/self.clip).
        """
        device = self.W.device
        dtype = self.W.dtype
        eps = 1e-8

        # детерминированный режим
        if deterministic:
            if clip:
                log_alpha = self.clip_func(2.0 * self.log_sigma - torch.log(self.W.pow(2) + eps))
                clip_mask = log_alpha.ge(self.thresh)  # True где надо обрезать
                W_eff = torch.where(clip_mask, torch.zeros_like(self.W), self.W)
                return torch.matmul(input, W_eff)
            else:
                return torch.matmul(input, self.W)

        # стохастический режим
        # поведение разделяется по размерности входа:
        if input.ndim == 2:
            # Вариационный шум на выходе (input-dependent std)
            W = self.W
            sigma2 = torch.exp(2.0 * self.log_sigma)  # var = exp(2*log_sigma)

            # в оригинале была опечатка clip_train — используем clip аргумент
            if clip:
                log_alpha = self.clip_func(2.0 * self.log_sigma - torch.log(self.W.pow(2) + eps))
                clip_mask = log_alpha.ge(self.thresh)
                W = torch.where(clip_mask, torch.zeros_like(self.W), W)
                sigma2 = torch.where(clip_mask, torch.zeros_like(sigma2), sigma2)

            mu = torch.matmul(input, W)  # (batch, out)
            si = torch.sqrt(torch.matmul(input * input, sigma2) + eps)  # (batch, out)

            noise = torch.randn(mu.shape, generator=self._srng, device=device, dtype=dtype)
            return mu + noise * si

        else:
            # input.ndim != 2 -> sample noisy weights once and apply to full input (e.g., sequence)
            # W_noisy = W + N(0,1) * exp(log_sigma)
            W_noise = torch.randn(self.W.shape, generator=self._srng, device=device, dtype=dtype) * torch.exp(self.log_sigma)
            W_noisy = self.W + W_noise

            if clip:
                log_alpha = self.clip_func(2.0 * self.log_sigma - torch.log(self.W.pow(2) + eps))
                clip_mask = log_alpha.ge(self.thresh)
                W_noisy = torch.where(clip_mask, torch.zeros_like(W_noisy), W_noisy)

            # input shape (batch, seq_len, in), W_noisy (in, out) -> output (batch, seq_len, out)
            return torch.matmul(input, W_noisy)

    def eval_reg(self, train_size: float):
        eps = 1e-8
        log_alpha = self.clip_func(2.0 * self.log_sigma - torch.log(self.W.pow(2) + eps))
        return alpha_regf(log_alpha).sum() / float(train_size)

    def get_ard(self):
        # возвращаем numpy-совместимую маску (как в оригинале)
        eps = 1e-8
        W_np = self.W.detach().cpu().numpy()
        logsigma_np = self.log_sigma.detach().cpu().numpy()
        log_alpha = 2.0 * logsigma_np - 2.0 * np.log(np.abs(W_np) + eps)
        return {"w": (log_alpha < self.thresh)}
    
    def forward(self, input: torch.Tensor, deterministic: bool = None, clip: bool = False, **kwargs) -> torch.Tensor:
        """
        input: tensor with last dim == num_inputs, can be 2D (batch, in) or 3D (batch, seq_len, in)
        deterministic: if None -> deterministic = not self.training (eval mode); else use explicit value
        clip: whether to apply clipping logic inside pre_activation
        """
        # по умолчанию привязываем deterministic к режиму модуля,
        # это удобно: model.eval() -> deterministic=True, model.train() -> deterministic=False
        if deterministic is None:
            deterministic = not self.training

        # получаем предактивацию (mu + noise*si или просто mu в deterministic режиме)
        out = self.pre_activation(input, deterministic=deterministic, clip=clip)

        # добавляем bias (broadcast по всем ведущим осям)
        out = out + self.b

        # применяем nonlinearity (может быть nn.Module или callable)
        return self.nonlinearity(out)

# %%
class LMNet(nn.Module):
    def __init__(self, vocab_size, n_hidden, config, hid_prop=False, batch_size=32, device='cpu'):
        """
        vocab_size: размер словаря
        n_hidden: размер скрытого состояния LSTM
        config: строка конфигурации (как в оригинале)
        hid_prop: если True — предусмотрена возможность прокинуть hid_init
        batch_size: использовался в оригинале при создании shared hid (32)
        device: 'cpu' или 'cuda'
        """
        super().__init__()
        self.vocab_size = int(vocab_size)
        self.n_hidden = int(n_hidden)
        self.config = config
        self.hid_prop = bool(hid_prop)
        self.batch_size = int(batch_size)
        self.device = device

        # LSTM: принимает вход feature dim = vocab_size
        # Передаём конфигурацию так, чтобы LSTM использовал те же настройки и инициализации
        self.lstm = BayesianLSTM(
            incoming=self.vocab_size,
            num_units=self.n_hidden,
            config=config[:3],
            only_return_final=False,
            learn_init=False,
            hid_prop=hid_prop
            # В твоём портированном BayesianLSTM можно добавить аргументы для инициализации ворот,
            # чтобы сохранить Orthogonal(...) и т.д.
        )

        # hid buffer — аналог theano.shared(np.zeros((2,32, n_hidden)))
        # сохраняем в качестве buffer чтобы было в state_dict, но не обучаемо
        if self.hid_prop:
            hid_tensor = torch.zeros((2, self.batch_size, self.n_hidden), dtype=torch.float32, device=self.device)
            # как в Theano, hid инициализируется нулями; в PyTorch сделаем buffer
            self.register_buffer('hid', hid_tensor)

        # dense: если hid_prop, в оригинале Dense применялся к определенному срезу LSTM-выхода;
        # здесь реализуем Dense, который можно вызвать на тензоре формы (batch, seq_len, n_hidden).
        if self.hid_prop:
            # В оригинале они брали SliceLayer(..., indices=0, axis=0) — в итоге Dense применялся по времени.
            # В PyTorch просто создаём Dense, который применяют к LSTM-выходу по временным шагам.
            DenseClass = BayesianDense_noLRT if config[-1] == "L" else Dense
            self.dense = DenseClass(incoming=self.n_hidden, num_units=self.vocab_size)
            # to_init_lstm в оригинале получали срез для инициализации LSTM в следующей итерации:
            # здесь мы будем извлекать последний скрытый (по времени) в forward: hid_to_init = hid_out[:, -1, :]
        else:
            DenseClass = BayesianDense if config[-1] == "L" else Dense
            self.dense = DenseClass(incoming=self.n_hidden, num_units=self.vocab_size)

        # softmax на последнем измерении; в оригинале они делали Reshape -> softmax,
        # мы сделаем то же в forward (flatten batch*seq, dim vocab) -> F.softmax
        self.softmax = nn.Softmax(dim=-1)

    def forward(self, inp, use_hid_init=False):
        """
        inp: LongTensor (batch, seq_len) — индексы слов (как T.imatrix)
        use_hid_init: если True и hid_prop=True — использовать self.hid как hid_init
        Возвращает: распределения (batch*seq_len, vocab_size) или (batch, seq_len, vocab_size) в зависимости от нужд.
        """
        # 1) one-hot (как T.eye(vocab_size)[inp])
        # inp shape: (batch, seq_len)
        inp = inp.to(device=self.device)
        one_hot = nn.functional.one_hot(inp, num_classes=self.vocab_size).float()  # (batch, seq_len, vocab_size)

        if self.hid_prop:
            b = one_hot.size(0)
            hid_init = self.hid_next[:, :b, :].clone() if hasattr(self, 'hid_next') else self.hid[:, :b, :].clone()
            # Передаем в LSTM
            lstm_out = self.lstm(one_hot, hid_init=hid_init)
            print(f"lstm_out.shape: {lstm_out.shape}")  # для отладки
            
            # last_hidden по последнему времени, detach чтобы не ломать граф градиента
            num_layers, batch_size, seq_len, hidden = lstm_out.shape
            last_hidden = lstm_out[:, :, -1, :].detach()
            
            # сохраняем для следующего батча, не мутируя граф
            self.hid_next = last_hidden.clone()
        else:
            lstm_out = self.lstm(one_hot)

        # 3) если hid_prop, to_init_lstm в оригинале = SliceLayer(self.lstm_layer, indices=-1, axis=2)
        # В практической цели to_init_lstm — часто последний скрытый слой; получим его по времени:
        # hid_to_init = last hidden across time (batch, n_hidden)
        # but original used axis=2 indices=-1 — это неочевидно; обычное значение — последний по времени:
        # last_hidden = lstm_out[:, -1, :]    # (batch, n_hidden)

        # 4) apply dense to every time step:
        # dense должен уметь принимать (..., in) тензор и вернуть (..., out)
        logits = self.dense(lstm_out[-1])  # expect (batch, seq_len, vocab_size)

        # 5) flatten (batch*seq_len, vocab) and softmax (как в оригинале Reshape + NonlinearityLayer(softmax))
        print(f'logits.shape: {logits.shape}')
        b, s, v = logits.shape
        logits_flat = logits.contiguous().view(-1, v)  # (batch*seq_len, vocab_size)
        probs_flat = self.softmax(logits_flat)         # (batch*seq_len, vocab_size)

        # вернуть также сырые формы, если нужно
        probs = probs_flat.view(b, s, v)  # (batch, seq_len, vocab_size)
        return probs, logits  # возвращаем и probs и logits (полезно для loss)

    # --- перенос compute_compression_masks и evaluate_compression, почти без изменений логики ---
    def compute_compression_masks(self):
        # get_ard у слоёв возвращает numpy-маски (в переводе мы сделали get_ard -> numpy)
        masks_lstm = self.lstm.get_ard()    # dict, как в оригинале
        masks_dense = self.dense.get_ard()  # dict, как в оригинале

        # aggregate z_masks (как в оригинале)
        mask_vocabulary = masks_lstm["z_input"]

        # если скрытая нейрон не влияет на LSTM, это не гарантирует, что он не влияет на Dense
        mask_hidden = np.logical_or(masks_lstm["z_hidden_by_w"], masks_dense["w"].any(axis=1))
        mask_hidden = np.logical_and(mask_hidden, masks_lstm["z_hidden"])

        # further compress w (в оригинале они модифицируют masks_lstm inplace)
        masks_lstm["w_input"][:, np.logical_not(mask_vocabulary), :] = 0
        masks_lstm["w_input"][:, :, np.logical_not(mask_hidden)] = 0
        masks_lstm["w_hidden"][:, np.logical_not(mask_hidden), :] = 0
        masks_lstm["w_hidden"][:, :, np.logical_not(mask_hidden)] = 0
        masks_dense["w"][np.logical_not(mask_hidden)] = 0

        # further compress gates
        masks_lstm["gates"][:, np.logical_not(mask_hidden)] = 0

        return mask_vocabulary, mask_hidden, masks_lstm["gates"], masks_lstm["w_input"], masks_lstm["w_hidden"], masks_dense["w"]

    def evaluate_compression(self):
        mask_vocabulary, mask_hidden, mask_gates, mask_w_inp, mask_w_hid, mask_w_dense = self.compute_compression_masks()

        # compute overall compression
        w_nonzero, w_all = 0.0, 0.0
        for w in [mask_w_inp, mask_w_hid, mask_w_dense]:
            w_nonzero += float(w.sum())
            w_all += float(w.size)
        overall_compression = w_all / (w_nonzero + 1e-8)

        # print compression per layer (как в оригинале)
        print("Compression per layers:")
        for layer_name, masks in [("LSTM", {"w_x":mask_w_inp, "w_h":mask_w_hid, "z_x":mask_vocabulary, "z_h":mask_hidden, "gates":mask_gates}), ("Dense", {"w":mask_w_dense})]:
            print(layer_name, end=": ")
            for key, matrix in masks.items():
                print("(%s: %d/%d)" % (key, int(matrix.sum()), matrix.size), end=" ")
            print()
        print("Overall compression:", overall_compression)
        return overall_compression

# %%
def get_char_lm_functions(
    net,
    hid_prop=False,
    grad_clip=1e9,
    learning_rate=0.001,
    loss_function=nn.functional.cross_entropy,
    val_loss_function=nn.functional.cross_entropy,
    train_size=1,
    test_types=("usual", "clip"),
):
    """
    Создаёт функции-обёртки для обучения и валидации в PyTorch стиле.
    """
    optimizer = torch.optim.Adam(net.parameters(), lr=learning_rate)

    # --- функция обучения ---
    def train_fn(inp, target):
        """
        inp: (batch, seq_len) LongTensor
        target: (batch, seq_len) LongTensor
        """
        net.train()
        optimizer.zero_grad()

        probs, logits = net(inp)  # forward: (batch, seq_len, vocab)
        # flatten (batch*seq, vocab)
        b, s, v = logits.shape
        logits_flat = logits.view(-1, v)
        target_flat = target.view(-1)

        # loss + рег
        loss = loss_function(logits_flat, target_flat)
        reg = 0.0
        for module in net.modules():
            if hasattr(module, "eval_reg"):
                reg = reg + module.eval_reg(train_size)
        loss = loss + reg

        loss.backward()
        # grad clipping
        torch.nn.utils.clip_grad_norm_(net.parameters(), grad_clip)
        optimizer.step()

        total_norm = sum(p.grad.detach().data.norm(2).item()**2 for p in net.parameters() if p.grad is not None)**0.5
        return loss.item(), total_norm

    # --- функции валидации ---
    val_fns = {}
    for t in test_types:
        clip = ("clip" in t)
        mc = ("MC" in t)

        def make_val_fn(clip=clip, mc=mc):
            def val_fn(inp, target):
                net.eval()
                with torch.no_grad():
                    if mc:
                        # 10 прогонов с шумом
                        preds = []
                        for _ in range(10):
                            probs, logits = net(inp)
                            preds.append(probs)
                        prediction = torch.stack(preds, dim=0).mean(0)
                    else:
                        probs, logits = net(inp)
                        prediction = probs

                    b, s, v = prediction.shape
                    target_flat = target.view(-1)
                    pred_flat = prediction.view(-1, v)
                    loss = val_loss_function(pred_flat, target_flat)
                    return loss.item()
            return val_fn

        val_fns[t] = make_val_fn()

    # --- пустая заглушка (для совместимости) ---
    def tmp_fn():
        return None

    # --- reset функции для hid ---
    if hid_prop:
        def reset_hid_init_fn():
            if hasattr(net, "hid"):
                net.hid.zero_()
        return train_fn, val_fns, tmp_fn, reset_hid_init_fn

    return train_fn, val_fns, tmp_fn


def train_char_lm_model(model, train_loader, test_loader, optimizer, criterion,
                        num_epochs, valid_loader=None,
                        grad_clip=10.0, print_fq=1, save_fq=0, file_name="model.pt",
                        sparsification_eval_fun=None, device="cpu"):
    print("Training ...")
    model.to(device)

    for epoch in range(1, num_epochs + 1):
        model.train()
        total_loss = 0.0
        total_tokens = 0
        grad_norm = 0.0

        for x, y in train_loader:  # PTBWordLoader → torch.Tensor
            optimizer.zero_grad()
            model_out = model(x)
            logits, _ = model_out  # LMNet forward: (batch, seq_len, vocab_size)
            
            loss = criterion(logits.view(-1, logits.size(-1)), y.view(-1))

            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), grad_clip)
            optimizer.step()

            total_loss += loss.item() * y.numel()
            total_tokens += y.numel()
            print(f"epoch: {epoch}/{num_epochs}; loss: {total_loss}; tokens: {total_tokens}")

            # для мониторинга нормы градиента
            grad_norm = max(grad_norm, torch.norm(
                torch.stack([p.grad.norm() for p in model.parameters() if p.grad is not None])
            ).item())

        avg_train_loss = total_loss / total_tokens

        # ----- Валидация -----
        if epoch % print_fq == 0 or epoch == num_epochs:
            def evaluate(loader, name="Val"):
                model.eval()
                loss_total, tokens_total = 0.0, 0
                with torch.no_grad():
                    for x, y in loader:
                        x, y = x.to(device), y.to(device)
                        logits, _ = model(x)
                        loss = criterion(logits.view(-1, logits.size(-1)), y.view(-1))
                        loss_total += loss.item() * y.numel()
                        tokens_total += y.numel()
                return loss_total / tokens_total

            val_loss = evaluate(valid_loader, "Val") if valid_loader else None
            test_loss = evaluate(test_loader, "Test")

            print(f"Epoch {epoch:03d} | "
                  f"Train loss {avg_train_loss:.4f} | "
                  f"Grad norm {grad_norm:.4f} | "
                  f"Val loss {val_loss:.4f} | Test loss {test_loss:.4f}")

            if sparsification_eval_fun:
                sparsification_eval_fun()

        # ----- Сохранение -----
        if save_fq and epoch % save_fq == 0:
            torch.save(model.state_dict(), f"{file_name}_epoch_{epoch}.pt")

    return model


class PTBWordLoader:
    def __init__(self, ptb_word, device="cpu"):
        self.ptb = ptb_word
        self.device = device

    def __iter__(self):
        self.ptb.new_epoch()
        for _ in range(self.ptb.num_batches):
            x, y = self.ptb.get_next_batch()   # numpy: (batch, seq_len)
            x_t = torch.tensor(x, dtype=torch.long, device=self.device)
            y_t = torch.tensor(y, dtype=torch.long, device=self.device)
            yield x_t, y_t

    def __len__(self):
        return self.ptb.num_batches

# %%
ptb_path = "Data/ptb/"
fnames = ["ptb.char.train.txt", "ptb.char.valid.txt", "ptb.char.test.txt"]

config = sys.argv[1] if len(sys.argv) > 1 else "LSTM"
file_name = f"Results/weights_{config}"

n_hidden = 256
seq_len = 35
grad_clip = 10
batch_size = 32
vocab_size = 10000
learning_rate = 0.002
hid_prop = True
num_epoches = 150
save_fq = 50
print_fq = 1
seed = 0

torch.manual_seed(seed)
np.random.seed(seed)

# %%
train_data, valid_data, test_data = load_PTB_word(ptb_path, *fnames)
train_data = PTB_word(train_data, seq_len, batch_size)
valid_data = PTB_word(valid_data, seq_len, batch_size)
test_data = PTB_word(test_data, seq_len, batch_size)

train_loader = PTBWordLoader(train_data)
valid_loader = PTBWordLoader(valid_data)
test_loader  = PTBWordLoader(test_data)
# Out:
# 10000

# %%
lm_net = LMNet(vocab_size, n_hidden, config, hid_prop, batch_size)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(lm_net.parameters(), lr=learning_rate)

# -----------------------------
# Обучение
# -----------------------------
lm_net = train_char_lm_model(
    lm_net, train_loader, test_loader, optimizer, criterion,
    num_epochs=num_epoches, valid_loader=valid_loader,
    print_fq=print_fq, save_fq=save_fq, file_name=file_name,
    sparsification_eval_fun=lm_net.evaluate_compression if hasattr(lm_net, "evaluate_compression") else None
)
# Out:
# Training ...
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 10315.584564208984; tokens: 1120
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 20631.156311035156; tokens: 2240
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 30946.671447753906; tokens: 3360
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 41261.38870239258; tokens: 4480
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 51564.56604003906; tokens: 5600
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 61862.403869628906; tokens: 6720
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 72144.88754272461; tokens: 7840
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 82414.68200683594; tokens: 8960
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 92689.32678222656; tokens: 10080
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 102952.84713745117; tokens: 11200
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 113216.60247802734; tokens: 12320
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 123487.36785888672; tokens: 13440
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 133764.13497924805; tokens: 14560
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 144029.90585327148; tokens: 15680
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 154299.67681884766; tokens: 16800
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 164563.4471130371; tokens: 17920
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 174832.20123291016; tokens: 19040
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 185104.96292114258; tokens: 20160
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 195368.8656616211; tokens: 21280
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 205623.29208374023; tokens: 22400
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 215881.07131958008; tokens: 23520
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 226141.85302734375; tokens: 24640
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 236404.63424682617; tokens: 25760
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 246664.41513061523; tokens: 26880
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 256925.1968383789; tokens: 28000
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 267184.97772216797; tokens: 29120
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 277437.7592468262; tokens: 30240
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 287688.5412597656; tokens: 31360
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 297960.3224182129; tokens: 32480
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 308219.10247802734; tokens: 33600
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 318480.88287353516; tokens: 34720
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 328749.6647644043; tokens: 35840
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 339013.4468078613; tokens: 36960
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 349262.22930908203; tokens: 38080
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 359527.01110839844; tokens: 39200
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 369792.7926635742; tokens: 40320
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 380048.5723876953; tokens: 41440
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 390320.35247802734; tokens: 42560
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 400589.1343688965; tokens: 43680
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 410860.9144592285; tokens: 44800
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 421132.6956176758; tokens: 45920
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 431399.47692871094; tokens: 47040
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 441651.25762939453; tokens: 48160
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 451925.0393676758; tokens: 49280
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 462202.82119750977; tokens: 50400
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 472469.60357666016; tokens: 51520
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 482735.3872680664; tokens: 52640
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 493010.1708984375; tokens: 53760
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 503293.95446777344; tokens: 54880
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 513569.7378540039; tokens: 56000
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 523839.52056884766; tokens: 57120
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 534091.3023376465; tokens: 58240
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 544344.0849304199; tokens: 59360
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 554611.8681335449; tokens: 60480
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 564889.6499633789; tokens: 61600
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 575164.43359375; tokens: 62720
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 585434.2163085938; tokens: 63840
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 595696.9996643066; tokens: 64960
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 605966.7823791504; tokens: 66080
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 616241.5660095215; tokens: 67200
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 626506.3478088379; tokens: 68320
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 636780.1295471191; tokens: 69440
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 647038.9128112793; tokens: 70560
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 657308.695526123; tokens: 71680
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 667592.479095459; tokens: 72800
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 677863.2615661621; tokens: 73920
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 688138.0451965332; tokens: 75040
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 698422.8285217285; tokens: 76160
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 708689.6119689941; tokens: 77280
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 718949.3939208984; tokens: 78400
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 729225.1773071289; tokens: 79520
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 739498.9601135254; tokens: 80640
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 749772.7418518066; tokens: 81760
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 760039.5252990723; tokens: 82880
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 770307.3085021973; tokens: 84000
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 780581.0913085938; tokens: 85120
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 790845.8741760254; tokens: 86240
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 801114.6571350098; tokens: 87360
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 811380.440826416; tokens: 88480
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 821647.2242736816; tokens: 89600
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 831916.007232666; tokens: 90720
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 842182.7896118164; tokens: 91840
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 852450.5717468262; tokens: 92960
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 862705.3538513184; tokens: 94080
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 872958.137512207; tokens: 95200
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 883218.9192199707; tokens: 96320
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 893465.7011413574; tokens: 97440
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 903738.4841918945; tokens: 98560
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 914009.2677307129; tokens: 99680
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 924282.05078125; tokens: 100800
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 934553.8340759277; tokens: 101920
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 944810.6167602539; tokens: 103040
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 955071.3995361328; tokens: 104160
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 965337.1832275391; tokens: 105280
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 975601.9650268555; tokens: 106400
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 985861.748046875; tokens: 107520
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 996138.5311889648; tokens: 108640
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1006407.3141479492; tokens: 109760
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1016683.0975341797; tokens: 110880
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1026952.8802490234; tokens: 112000
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1037221.6632080078; tokens: 113120
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1047487.4458312988; tokens: 114240
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1057742.2290039062; tokens: 115360
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1068014.0112304688; tokens: 116480
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1078280.7946777344; tokens: 117600
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1088560.5781555176; tokens: 118720
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1098832.3614501953; tokens: 119840
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1109092.1434020996; tokens: 120960
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1119366.9259643555; tokens: 122080
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1129641.7095947266; tokens: 123200
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1139909.4917297363; tokens: 124320
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1150184.2742919922; tokens: 125440
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1160458.0560302734; tokens: 126560
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1170733.839416504; tokens: 127680
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1181008.6219787598; tokens: 128800
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1191285.4040527344; tokens: 129920
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1201561.1853027344; tokens: 131040
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1211832.968597412; tokens: 132160
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1222101.7504882812; tokens: 133280
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1232381.5328979492; tokens: 134400
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1242642.314605713; tokens: 135520
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1252909.0969848633; tokens: 136640
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1263180.8770751953; tokens: 137760
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1273452.6593017578; tokens: 138880
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1283714.4429016113; tokens: 140000
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1293983.2247924805; tokens: 141120
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1304247.0079040527; tokens: 142240
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1314524.790802002; tokens: 143360
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1324787.5741577148; tokens: 144480
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1335060.357208252; tokens: 145600
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1345325.1390075684; tokens: 146720
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1355596.9212341309; tokens: 147840
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1365877.7033996582; tokens: 148960
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1376146.4863586426; tokens: 150080
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1386420.269165039; tokens: 151200
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1396686.05178833; tokens: 152320
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1406954.8347473145; tokens: 153440
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1417217.617034912; tokens: 154560
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1427483.4007263184; tokens: 155680
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1437761.1836242676; tokens: 156800
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1448031.967163086; tokens: 157920
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1458305.7489013672; tokens: 159040
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1468584.532623291; tokens: 160160
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1478847.315979004; tokens: 161280
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1489119.0982055664; tokens: 162400
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1499379.87991333; tokens: 163520
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1509632.6625061035; tokens: 164640
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1519890.444946289; tokens: 165760
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1530159.2268371582; tokens: 166880
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1540430.0093078613; tokens: 168000
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1550702.7923583984; tokens: 169120
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1560964.575958252; tokens: 170240
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1571226.3595581055; tokens: 171360
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1581496.1422729492; tokens: 172480
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1591769.9250793457; tokens: 173600
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1602030.7078552246; tokens: 174720
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1612292.4914550781; tokens: 175840
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1622536.275177002; tokens: 176960
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1632791.0572814941; tokens: 178080
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1643050.8392333984; tokens: 179200
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1653317.622680664; tokens: 180320
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1663578.405456543; tokens: 181440
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1673836.1889648438; tokens: 182560
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1684088.9726257324; tokens: 183680
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1694357.7555847168; tokens: 184800
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1704612.5387573242; tokens: 185920
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1714872.3217773438; tokens: 187040
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1725131.1039733887; tokens: 188160
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1735408.886871338; tokens: 189280
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1745672.6699829102; tokens: 190400
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1755939.4534301758; tokens: 191520
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1766211.2367248535; tokens: 192640
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1776486.0203552246; tokens: 193760
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1786772.8031921387; tokens: 194880
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1797052.5866699219; tokens: 196000
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1807311.369934082; tokens: 197120
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1817594.1526794434; tokens: 198240
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1827870.9358215332; tokens: 199360
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1838149.719543457; tokens: 200480
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1848426.5026855469; tokens: 201600
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1858703.2858276367; tokens: 202720
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1868972.068786621; tokens: 203840
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1879240.8517456055; tokens: 204960
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1889512.6350402832; tokens: 206080
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1899773.417816162; tokens: 207200
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1910053.2012939453; tokens: 208320
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1920322.984008789; tokens: 209440
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1930574.765777588; tokens: 210560
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1940840.548400879; tokens: 211680
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1951110.3311157227; tokens: 212800
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1961373.1144714355; tokens: 213920
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1971639.8979187012; tokens: 215040
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1981902.681274414; tokens: 216160
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 1992177.4649047852; tokens: 217280
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2002455.2478027344; tokens: 218400
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2012737.0307922363; tokens: 219520
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2023022.813873291; tokens: 220640
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2033303.5971069336; tokens: 221760
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2043576.3790893555; tokens: 222880
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2053846.1618041992; tokens: 224000
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2064121.9451904297; tokens: 225120
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2074396.7277526855; tokens: 226240
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2084655.5099487305; tokens: 227360
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2094918.2933044434; tokens: 228480
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2105192.0750427246; tokens: 229600
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2115466.8586730957; tokens: 230720
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2125737.642211914; tokens: 231840
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2136015.4251098633; tokens: 232960
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2146288.2081604004; tokens: 234080
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2156565.9910583496; tokens: 235200
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2166835.7737731934; tokens: 236320
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2177104.5556640625; tokens: 237440
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2187382.3385620117; tokens: 238560
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2197660.1203918457; tokens: 239680
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2207937.903289795; tokens: 240800
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2218220.6860351562; tokens: 241920
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2228498.4678649902; tokens: 243040
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2238768.250579834; tokens: 244160
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2249046.032409668; tokens: 245280
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2259314.8153686523; tokens: 246400
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2269579.598236084; tokens: 247520
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2279842.3805236816; tokens: 248640
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2290113.1640625; tokens: 249760
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2300382.9467773438; tokens: 250880
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2310642.7297973633; tokens: 252000
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2320928.512878418; tokens: 253120
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2331199.295349121; tokens: 254240
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2341457.0777893066; tokens: 255360
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2351717.8605651855; tokens: 256480
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2361988.644104004; tokens: 257600
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2372255.4275512695; tokens: 258720
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2382526.211090088; tokens: 259840
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2392796.9946289062; tokens: 260960
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2403067.7781677246; tokens: 262080
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2413345.561065674; tokens: 263200
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2423600.3442382812; tokens: 264320
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2433861.125946045; tokens: 265440
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2444129.907836914; tokens: 266560
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2454402.690887451; tokens: 267680
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2464683.4741210938; tokens: 268800
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2474953.2568359375; tokens: 269920
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2485219.0405273438; tokens: 271040
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2495494.823913574; tokens: 272160
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2505757.606201172; tokens: 273280
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2516033.3895874023; tokens: 274400
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2526299.1722106934; tokens: 275520
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2536576.9551086426; tokens: 276640
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2546850.737915039; tokens: 277760
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2557121.5214538574; tokens: 278880
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2567401.3049316406; tokens: 280000
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2577695.088195801; tokens: 281120
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2587968.8710021973; tokens: 282240
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2598235.654449463; tokens: 283360
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2608506.4379882812; tokens: 284480
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2618782.2213745117; tokens: 285600
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2629050.0045776367; tokens: 286720
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2639318.787536621; tokens: 287840
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2649588.570251465; tokens: 288960
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2659859.352722168; tokens: 290080
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2670121.1352539062; tokens: 291200
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2680384.9183654785; tokens: 292320
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2690645.700073242; tokens: 293440
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2700911.4837646484; tokens: 294560
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2711181.266479492; tokens: 295680
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2721460.049133301; tokens: 296800
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2731732.8311157227; tokens: 297920
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2741985.613708496; tokens: 299040
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2752254.3955993652; tokens: 300160
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2762511.1782836914; tokens: 301280
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2772780.960998535; tokens: 302400
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2783037.7436828613; tokens: 303520
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2793313.527069092; tokens: 304640
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2803585.3103637695; tokens: 305760
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2813850.093231201; tokens: 306880
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2824119.875946045; tokens: 308000
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2834388.657836914; tokens: 309120
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2844649.440612793; tokens: 310240
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2854928.224334717; tokens: 311360
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2865201.007385254; tokens: 312480
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2875473.789367676; tokens: 313600
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2885745.5715942383; tokens: 314720
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2896027.353515625; tokens: 315840
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2906286.13571167; tokens: 316960
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2916549.917755127; tokens: 318080
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2926829.70123291; tokens: 319200
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2937101.4834594727; tokens: 320320
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2947370.266418457; tokens: 321440
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2957644.0492248535; tokens: 322560
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2967918.8328552246; tokens: 323680
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2978198.616333008; tokens: 324800
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2988465.3997802734; tokens: 325920
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 2998744.1835021973; tokens: 327040
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3009017.9652404785; tokens: 328160
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3019302.7474975586; tokens: 329280
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3029581.5312194824; tokens: 330400
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3039865.3147888184; tokens: 331520
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3050149.0983581543; tokens: 332640
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3060421.8814086914; tokens: 333760
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3070692.6649475098; tokens: 334880
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3080973.4481811523; tokens: 336000
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3091243.230895996; tokens: 337120
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3101511.014099121; tokens: 338240
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3111773.797454834; tokens: 339360
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3122048.58001709; tokens: 340480
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3132320.3622436523; tokens: 341600
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3142587.1446228027; tokens: 342720
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3152856.9273376465; tokens: 343840
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3163129.7103881836; tokens: 344960
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3173409.493865967; tokens: 346080
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3183685.276184082; tokens: 347200
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3193956.0597229004; tokens: 348320
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3204213.843231201; tokens: 349440
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3214480.626678467; tokens: 350560
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3224747.409057617; tokens: 351680
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3235009.1915893555; tokens: 352800
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3245251.9734191895; tokens: 353920
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3255517.7560424805; tokens: 355040
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3265788.5385131836; tokens: 356160
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3276047.3217773438; tokens: 357280
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3286300.104370117; tokens: 358400
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3296560.886077881; tokens: 359520
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3306818.6695861816; tokens: 360640
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3317082.452697754; tokens: 361760
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3327348.235321045; tokens: 362880
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3337613.0181884766; tokens: 364000
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3347864.7999572754; tokens: 365120
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3358105.5822753906; tokens: 366240
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3368359.3646240234; tokens: 367360
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3378620.146331787; tokens: 368480
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3388882.9286193848; tokens: 369600
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3399154.7108459473; tokens: 370720
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3409419.4926452637; tokens: 371840
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3419687.2758483887; tokens: 372960
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3429951.0578918457; tokens: 374080
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3440206.8397521973; tokens: 375200
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3450470.6217956543; tokens: 376320
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3460756.404876709; tokens: 377440
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3471011.186981201; tokens: 378560
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 3481264.969329834; tokens: 379680
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# ...
# epoch: 1/150; loss: 8410081.697235107; tokens: 917280
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 8420343.480834961; tokens: 918400
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 8430606.263122559; tokens: 919520
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 8440883.045196533; tokens: 920640
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 8451165.827941895; tokens: 921760
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 8461443.610839844; tokens: 922880
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 8471712.392730713; tokens: 924000
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 8481983.176269531; tokens: 925120
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 8492260.958099365; tokens: 926240
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 8502525.739898682; tokens: 927360
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# epoch: 1/150; loss: 8512790.521697998; tokens: 928480
# lstm_out.shape: torch.Size([2, 32, 33, 256])
# logits.shape: torch.Size([32, 33, 10000])
# epoch: 1/150; loss: 8522481.831542969; tokens: 929536
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 29, 256])
# logits.shape: torch.Size([32, 29, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 35, 256])
# logits.shape: torch.Size([32, 35, 10000])
# lstm_out.shape: torch.Size([2, 32, 19, 256])
# logits.shape: torch.Size([32, 19, 10000])
# Epoch 001 | Train loss 9.1685 | Grad norm 0.2419 | Val loss 9.1693 | Test loss 9.1599
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[71], line 9
#       4 optimizer = optim.Adam(lm_net.parameters(), lr=learning_rate)
#       6 # -----------------------------
#       7 # Обучение
#       8 # -----------------------------
# ----> 9 lm_net = train_char_lm_model(
#      10     lm_net, train_loader, test_loader, optimizer, criterion,
#      11     num_epochs=num_epoches, valid_loader=valid_loader,
#      12     print_fq=print_fq, save_fq=save_fq, file_name=file_name,
#      13     sparsification_eval_fun=lm_net.evaluate_compression if hasattr(lm_net, "evaluate_compression") else None
#      14 )
#
# Cell In[70], line 149, in train_char_lm_model(model, train_loader, test_loader, optimizer, criterion, num_epochs, valid_loader, grad_clip, print_fq, save_fq, file_name, sparsification_eval_fun, device)
#     143     print(f"Epoch {epoch:03d} | "
#     144           f"Train loss {avg_train_loss:.4f} | "
#     145           f"Grad norm {grad_norm:.4f} | "
#     146           f"Val loss {val_loss:.4f} | Test loss {test_loss:.4f}")
#     148     if sparsification_eval_fun:
# --> 149         sparsification_eval_fun()
#     151 # ----- Сохранение -----
#     152 if save_fq and epoch % save_fq == 0:
#
# Cell In[68], line 129, in LMNet.evaluate_compression(self)
#     128 def evaluate_compression(self):
# --> 129     mask_vocabulary, mask_hidden, mask_gates, mask_w_inp, mask_w_hid, mask_w_dense = self.compute_compression_masks()
#     131     # compute overall compression
#     132     w_nonzero, w_all = 0.0, 0.0
#
# Cell In[68], line 117, in LMNet.compute_compression_masks(self)
#     114 mask_hidden = np.logical_and(mask_hidden, masks_lstm["z_hidden"])
#     116 # further compress w (в оригинале они модифицируют masks_lstm inplace)
# --> 117 masks_lstm["w_input"][:, np.logical_not(mask_vocabulary), :] = 0
#     118 masks_lstm["w_input"][:, :, np.logical_not(mask_hidden)] = 0
#     119 masks_lstm["w_hidden"][:, np.logical_not(mask_hidden), :] = 0
#
# RuntimeError: masked_fill_ only supports boolean masks, but got mask with dtype unsigned char

# %%
# -----------------------------
# Сохранение
# -----------------------------
torch.save(lm_net.state_dict(), file_name + ".pt")
